# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
# %matplotlib inline

# %%
customers = pd.read_csv("data/customers.txt", sep='\t')

# %%
orders = pd.read_csv("data/orders.txt", encoding='cp1251', sep='\t')

# %%
orders.head(2)
# Out:
#    orderid  customerid  campaignid  orderdate          city state zipcode  \
# 0  1002854       45978        2141 2009-10-13        NEWTON    MA   02459
# 1  1002855      125381        2173 2009-10-13  NEW ROCHELLE    NY   10804
#
#   paymenttype  totalprice  numorderlines  numunits  year
# 0          VI       190.0              3         3  2009
# 1          VI        10.0              1         1  2009

# %%
orders["orderdate"] = pd.to_datetime(orders["orderdate"])

# %%
orders.orderdate.ftype
# Out:
# 'datetime64[ns]:dense'

# %%
orders["year"] = orders["orderdate"].dt.year

# %%
orders.head(2)
# Out:
#    orderid  customerid  campaignid  orderdate          city state zipcode  \
# 0  1002854       45978        2141 2009-10-13        NEWTON    MA   02459
# 1  1002855      125381        2173 2009-10-13  NEW ROCHELLE    NY   10804
#
#   paymenttype  totalprice  numorderlines  numunits  year
# 0          VI       190.0              3         3  2009
# 1          VI        10.0              1         1  2009

# %%
merged = pd.merge(left=orders, right=customers, on="customerid")

# %%
merged.head(2)
# Out:
#    orderid  customerid  campaignid  orderdate          city state zipcode  \
# 0  1002854       45978        2141 2009-10-13        NEWTON    MA   02459
# 1  1002855      125381        2173 2009-10-13  NEW ROCHELLE    NY   10804
#
#   paymenttype  totalprice  numorderlines  numunits  year  householdid gender  \
# 0          VI       190.0              3         3  2009     18991234      M
# 1          VI        10.0              1         1  2009     36173848      M
#
#   firstname
# 0     LOUIS
# 1   ANTHONY

# %%
merged.orderdate[5] - merged.orderdate[4]
# Out:
# Timedelta('-400 days +00:00:00')

# %%
older_than = merged[merged.orderdate < '2016-01-01']

# %%
timedeltas = (merged[merged.orderdate > '2016-01-01'].groupby("householdid").orderdate.max() - merged[merged.orderdate > '2016-01-01'].groupby("householdid").orderdate.min())

# %%
timedeltas = (merged[merged.orderdate > '2016-01-01'].groupby("householdid").orderdate.max()- pd.to_datetime('2016-01-01'))

# %%
timedeltas.groupby(timedeltas.get_values()).count().sort_values().plot()

# %%
timedeltas.groupby(timedeltas.get_values()).aggregate('sum')
# Out:
# 1 days        48 days
# 2 days       174 days
# 3 days       243 days
# 4 days       288 days
# 5 days       300 days
# 6 days       390 days
# 7 days       273 days
# 8 days       352 days
# 9 days       711 days
# 10 days      490 days
# 11 days      517 days
# 12 days      792 days
# 13 days      572 days
# 14 days      392 days
# 15 days      690 days
# 16 days     1376 days
# 17 days     1020 days
# 18 days     1044 days
# 19 days     1311 days
# 20 days      820 days
# 21 days      609 days
# 22 days     1386 days
# 23 days     1817 days
# 24 days     1512 days
# 25 days     2100 days
# 26 days     1482 days
# 27 days     1269 days
# 28 days     1092 days
# 29 days     1711 days
# 30 days     2370 days
#               ...
# 234 days   16146 days
# 235 days   17155 days
# 236 days   12744 days
# 237 days   12087 days
# 238 days   11900 days
# 239 days   12428 days
# 240 days    9120 days
# 241 days   13978 days
# 242 days   10648 days
# 243 days    8262 days
# ...

# %%
timedeltas = (merged[merged.orderdate > '2016-01-01'].groupby("householdid").orderdate.max() - merged[merged.orderdate > '2016-01-01'].groupby("householdid").orderdate.min())
timedeltas.plot()

# %%
dir(merged[merged.orderdate > '2016-01-01'].groupby("householdid").orderdate.max() - merged[merged.orderdate > '2016-01-01'].groupby("householdid").orderdate.min())
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
#orders.groupby("customerid")["orderdate"].min()

# %%
#orders.join(customers, "customerid")
